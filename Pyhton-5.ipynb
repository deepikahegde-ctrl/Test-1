# %% [raw]
# Objective:
# The main goal of this assignment is to conduct a thorough exploratory analysis of the "cardiographic.csv" dataset to uncover insights, identify patterns, and understand the dataset's underlying structure. You will use statistical summaries, visualizations, and data manipulation techniques to explore the dataset comprehensively.
# Dataset:
# 1.	LB - Likely stands for "Baseline Fetal Heart Rate (FHR)" which represents the average fetal heart rate over a period.
# 2.	AC - Could represent "Accelerations" in the FHR. Accelerations are usually a sign of fetal well-being.
# 3.	FM - May indicate "Fetal Movements" detected by the monitor.
# 4.	UC - Likely denotes "Uterine Contractions", which can impact the FHR pattern.
# 5.	DL - Could stand for "Decelerations Late" with respect to uterine contractions, which can be a sign of fetal distress.
# 6.	DS - May represent "Decelerations Short" or decelerations of brief duration.
# 7.	DP - Could indicate "Decelerations Prolonged", or long-lasting decelerations.
# 8.	ASTV - Might refer to "Percentage of Time with Abnormal Short Term Variability" in the FHR.
# 9.	MSTV - Likely stands for "Mean Value of Short Term Variability" in the FHR.
# 10.	ALTV - Could represent "Percentage of Time with Abnormal Long Term Variability" in the FHR.
# 11.	MLTV - Might indicate "Mean Value of Long Term Variability" in the FHR.

# %% [raw]
# Tasks:
# 1.	Data Cleaning and Preparation:
# ●	Load the dataset into a data frame or equivalent data structure.
# ●	Handle missing values appropriately (e.g., imputation, deletion).
# ●	Identify and correct any inconsistencies in data types (e.g., numerical values stored as strings).
# ●	Detect and treat outliers if necessary.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('cardiotocographic.csv')
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
df.tail()
# Out:
#          LB        AC        FM        UC   DL   DS   DP  ASTV  MSTV  \
# 2121  140.0  0.000000  0.961268  0.007426  0.0  0.0  0.0  79.0   0.2
# 2122  140.0  0.000775  0.000000  0.006979  0.0  0.0  0.0  78.0   0.4
# 2123  140.0  0.000980  0.000000  0.006863  0.0  0.0  0.0  79.0   0.4
# 2124  140.0  0.000679  0.000000  0.006110  0.0  0.0  0.0  78.0   0.4
# 2125  142.0  0.001616 -0.000188  0.008078  0.0  0.0  0.0  74.0   0.4
#
#            ALTV  MLTV  Width  Tendency       NSP
# 2121  25.000000   7.2   40.0       0.0  2.000000
# 2122  22.000000   7.1   66.0       1.0  2.000000
# 2123  20.000000   6.1   67.0       1.0  1.990464
# 2124  27.000000   7.0   66.0       1.0  2.000000
# 2125  35.857183   5.0   42.0       0.0  1.000000

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df[df.duplicated()]
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1115  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1458  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1115   39.0       0.0  1.0
# 1458   35.0       0.0  1.0

# %%
df.drop_duplicates(inplace=True,ignore_index=True)
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2119  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2120  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2121  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2123  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
df.LB.mean()
# Out:
# 133.3420230800519

# %%
df.AC.mean()
# Out:
# 0.0032197961979291345

# %%
df.DS.mean()
# Out:
# 2.511369605097549e-06

# %%
df.DP.mean()
# Out:
# 0.00017531778446317666

# %%
df.MLTV.mean()
# Out:
# 8.28054590298053

# %%
df.Width.mean()
# Out:
# 70.46105246796047

# %%
df.Tendency.mean()
# Out:
# 0.31667228014592036

# %%
df.NSP.mean()
# Out:
# 1.304796768239931

# %%
df.fillna({'LB':df.LB.mean(),
           'AC':df.AC.mean(),
           'DS':df.DS.mean(),
           'DP':df.DP.mean(),
           'MLTV':df.MLTV.mean(),
           'Width':df.Width.mean(),
           'Tendency':df.Tendency.mean(),
           'NSP':df.NSP.mean()},
          inplace=True)

# %%
df.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
cols_to_convert = ['LB','AC','FM','UC','DL','DS','DP','ASTV','MSTV','ALTV','MLTV','Width','Tendency','NSP']
df[cols_to_convert]=df[cols_to_convert].apply(pd.to_numeric)
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2119  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2120  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2121  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2123  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
col=df.columns

# %%
## Outlier detection
for col in df.columns:
    print(col)
    sns.boxplot(data=df,y=col)
    plt.show()
# Out:
# LB
# AC
# FM
# UC
# DL
# DS
# DP
# ASTV
# MSTV
# ALTV
# MLTV
# Width
# Tendency
# NSP

# %%
### outlier capping
def outlier_capping(df,column):
    Q1=df[column].quantile(0.25)
    Q3=df[column].quantile(0.75)
    IQR=Q3-Q1
    lower_extreme=Q1-1.5*IQR
    upper_extreme=Q3+1.5*IQR
    df[column]=df[column].apply(lambda x: lower_extreme if x<lower_extreme else upper_extreme if x>upper_extreme else x )
for col in df.select_dtypes(include=['int','float']).columns:
        outlier_capping(df,col)

# %%
for col in df.columns:  
    print(col)
    sns.boxplot(data=df,y=col)
    plt.show()
# Out:
# LB
# AC
# FM
# UC
# DL
# DS
# DP
# ASTV
# MSTV
# ALTV
# MLTV
# Width
# Tendency
# NSP

# %% [markdown]
# ### 2.	Statistical Summary:

# %% [raw]
# ●	Provide a statistical summary for each variable in the dataset, including measures of central tendency (mean, median) and dispersion (standard deviation, interquartile range).
# ●	Highlight any interesting findings from this summary.

# %%
summary = pd.DataFrame({
    "Mean":df.mean(),
    "Meadian":df.median(),
    "Std dev":df.std(),
    "Q1":df.quantile(0.25),
    "Q3":df.quantile(0.75),
    "IQR":df.quantile(0.75) - df.quantile(0.25)
})

summary
# Out:
#                 Mean     Meadian    Std dev          Q1          Q3        IQR
# LB        133.292103  133.000000   9.926749  126.000000  140.000000  14.000000
# AC          0.003148    0.001668   0.003827    0.000000    0.005612   0.005612
# FM          0.001570    0.000000   0.002487    0.000000    0.002568   0.002568
# UC          0.004365    0.004486   0.003001    0.001858    0.006536   0.004678
# DL          0.001772    0.000000   0.002670    0.000000    0.003292   0.003292
# DS          0.000000    0.000000   0.000000    0.000000    0.000000   0.000000
# DP          0.000000    0.000000   0.000000    0.000000    0.000000   0.000000
# ASTV       46.998334   49.000000  17.609911   32.000000   61.000000  29.000000
# MSTV        1.304554    1.200000   0.781303    0.700000    1.700000   1.000000
# ALTV        6.697979    0.000000  10.381254    0.000000   11.000000  11.000000
# MLTV        8.011618    7.500000   5.046504    4.600000   10.800000   6.200000
# ...

# %% [raw]
# LB:
# mean and median are close to each other so it is a symmetric dostribution.
# standared deviation moderate so some deviations in the fetal heart rate.
#
# AC:
# The values are near zero so the accelerations are rare in records.
# median is 0 and mean is slightly greater than 0 :skewed distribution with occasional higher values.
#
# FM:
# same as AC but with ocationally higher value.
# Indicates variability in fetal activity.
#
# ASTV:
# Some record shows high percentages while others are in low.

# %% [markdown]
# ### 3.	Data Visualization:

# %% [raw]
# ●	Create histograms or boxplots to visualize the distributions of various numerical variables.
# ●	Use bar charts or pie charts to display the frequency of categories for categorical variables.
# ●	Generate scatter plots or correlation heatmaps to explore relationships between pairs of variables.
# ●	Employ advanced visualization techniques like pair plots, or violin plots for deeper insights.

# %%
num_col=df.columns
num_col
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %% [markdown]
# ### Histogram

# %%
plt.figure(figsize=(15,10))
for i in range(len(num_col)):
    plt.subplot(4,4,i+1)
    sns.histplot(data=df[num_col[i]])
    plt.tight_layout()

# %% [markdown]
# ### Boxplot

# %%
plt.figure(figsize=(14,10))
for i in range(len(num_col)):
    plt.subplot(4,4,i+1)
    sns.boxplot(data=df[num_col[i]])
    plt.tight_layout()

# %% [markdown]
# ### Barchart

# %%
sns.countplot(x=df['NSP'])
plt.title("Frequency of NSP categories")
plt.show()

# %%
num_col=df.select_dtypes(include=['int','float']).columns
cat_col=df.select_dtypes(include=['object']).columns

# %%
num_col
# Out:
# Index(['LB', 'AC', 'FM', 'UC', 'DL', 'DS', 'DP', 'ASTV', 'MSTV', 'ALTV',
#        'MLTV', 'Width', 'Tendency', 'NSP'],
#       dtype='object')

# %%
cat_col
# Out:
# Index([], dtype='object')

# %% [markdown]
# ### correlation

# %%
corr=df[num_col].corr()
corr
# Out:
#                 LB        AC        FM        UC        DL  DS  DP      ASTV  \
# LB        1.000000 -0.081669 -0.006815 -0.163308 -0.156278 NaN NaN  0.285463
# AC       -0.081669  1.000000  0.076091  0.093575 -0.102934 NaN NaN -0.273178
# FM       -0.006815  0.076091  1.000000 -0.318156 -0.018024 NaN NaN  0.155798
# UC       -0.163308  0.093575 -0.318156  1.000000  0.268151 NaN NaN -0.217484
# DL       -0.156278 -0.102934 -0.018024  0.268151  1.000000 NaN NaN -0.112289
# DS             NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# DP             NaN       NaN       NaN       NaN       NaN NaN NaN       NaN
# ASTV      0.285463 -0.273178  0.155798 -0.217484 -0.112289 NaN NaN  1.000000
# MSTV     -0.295018  0.217933  0.070412  0.298462  0.566625 NaN NaN -0.433731
# ALTV      0.322748 -0.409830 -0.013820 -0.294226 -0.296383 NaN NaN  0.438800
# MLTV     -0.042276 -0.152034 -0.036314 -0.072965 -0.242174 NaN NaN -0.323958
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corr,annot=True)
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.pairplot(df[num_col],diag_kind='kde')

# %% [raw]
# ASTV  vs ALTV:
# LIkely positively correlated(both measure abnormal variability).if one is high the other is too
#
# LB(Baseline FHR) vs Variability measures(MSTV,MLTV) :
# Wewk correlation,meaning baseline heart rate does not strongly predict variability.
#
# AC(Acceleration) vs FM(Fetal Movement):
# Possible positive correlatiom=more fetal movements often come with acceleration in heart rate.

# %% [raw]
# * Baseline FHR(LB) Most values cluster around 120 to 140bpm, which is within the normal fetal heart rate range. mean and median are xlose,showing a fairly balanced distribution.
#
# * Acceleration(AC) & Fetal Movement(FM) :
# Often recorded as zero, but occasionally spike.This makes the data skewed(lots of zeros,few hig values).This spikes usually signal fetal activity and weel-being.
#
# Abnormal variability(ASTV AND ALTV):
# Some records show very high abnormal variability,while others are low. This wide spread suggesrs strong differences in fetal health conditions across cases.
#
#
# Symmetry vs Skewness:
# LB is symmetric(healthy heart rate distribution), while AC/FM are skewed(rare but important spikes).
#
# outliers:
# ASTV has extreme values in some cases,pointing to possible fetal distress.
#
#
# Medical Decision Making: Doctors can focus on ASTV and ALTV as key warning signs.High values may prompt closer mnitoring or intervention.
# Build predictive models
# Explore clustering to group similar fetal patterns.
